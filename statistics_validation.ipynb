# %%
import pandas as pd
from scipy.stats import ttest_ind
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e0942d1b-e7dc-4d13-a688-1adb0e43e235" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e0942d1b-e7dc-4d13-a688-1adb0e43e235">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv(next(iter(uploaded)))

# %%
print(df.head())
# Out:
#    Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0          101  Female   29       New York            Gold      1120.20
# 1          102    Male   34    Los Angeles          Silver       780.50
# 2          103  Female   43        Chicago          Bronze       510.75
# 3          104    Male   30  San Francisco            Gold      1480.30
# 4          105    Male   27          Miami          Silver       720.40
#
#    Items Purchased  Average Rating  Discount Applied  \
# 0               14             4.6              True
# 1               11             4.1             False
# 2                9             3.4              True
# 3               19             4.7             False
# 4               13             4.0              True
#
#    Days Since Last Purchase Satisfaction Level
# 0                        25          Satisfied
# 1                        18            Neutral
# 2                        42        Unsatisfied
# ...

# %%
discount=df[df['Discount Applied']=='YES']['Total Spend']
no_discount=df[df['Discount Applied']=='NO']['Total Spend']

# %%
t_stat,p_value=ttest_ind(discount,no_discount)
# Out:
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/deprecation.py:234: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return f(*args, **kwargs)

# %%
print("T-Statistics:",t_stat)
print("P-value:",p_value)
# Out:
# T-Statistics: nan
# P-value: nan

# %%
if p_value<0.05:
  print("Discounts significantly affect customer spending.")
else:
  print("Discounts do not significantly affect customer spending.")
# Out:
# Discounts do not significantly affect customer spending.
